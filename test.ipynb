# %%
! pip install ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 8.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]3 [ipywidgets]
# ...

# %%
import json
from generator import *
from model_training import *
import time
from config import *
import os

# %%
file = open("geojson.json", "r")
data = json.load(file)
file.close()

hexagon_geojson = json.loads(data["hexagonGeoJson"])
network_inp_content = data["inpContent"]
crs = data["crsCode"]
hexagon_radius = data["hexagonRadius"]
step3_sensor_attachments = data["step3SelectedNodeIds"]

# %%
os.makedirs("./data", exist_ok= True)
files = [x for x in os.listdir('./data')]

# %%
print(len(files))
# Out:
# 0

# %%
os.path.getsize("/home/timmy/sensitivityAnalysis/train_data/train_data0")
# Out:
# 77163574
